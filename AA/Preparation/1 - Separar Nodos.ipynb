# %% [markdown]
# ## Importa los módulos necesarios y establece configuraciones

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import funs
import seaborn as sns
import plotly.plotly as py
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
pd.options.display.max_rows = 10
# Out:
# C:\Users\Jergb\Anaconda3\lib\site-packages\ggplot\utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Importa el .csv que contiene las mediciones de todos los nodos

# %%
#df = pd.read_csv('all_nodos.csv')
df = pd.read_csv('Variables.csv')
df
# Out:
#        id_Variable  id_nodo  Temperatura  Humedad  Hum. Tierra  Nivel_UV  \
# 0                1        4            0        0         0.00         0
# 1                2        5            0        0         0.00         0
# 2                3        3           30       42         0.01         0
# 3                4        2           30       44         0.01         0
# 4                5        6           30       44         0.01        12
# ...            ...      ...          ...      ...          ...       ...
# 66630        66631        5           22       22         8.68         0
# 66631        66632        2           23       21         2.26        12
# 66632        66633        5           22       22         8.68         0
# 66633        66634        2           22       22         3.22        12
# 66634        66635        5           22       22         8.68         0
#
#        INT. LUMÍN  Carga  RSSI  T_SERVIDOR  T_NODO  TRY  FECHA   AÑO  MES  \
# 0               0   0.00    39         336     170   63    NaN  2018    4
# 1               0   0.00     0        1926    1678   63    NaN  2018    4
# 2            1038   0.60    55           0     117   68    NaN  2018    4
# 3             791 -11.67    56           0     105    0    NaN  2018    4
# 4            5777   0.59    46         291     125    0    NaN  2018    4
# ...           ...    ...   ...         ...     ...  ...    ...   ...  ...
# 66630        5085 -11.67    40           0     108    0    NaN  2018    6
# 66631        5219 -11.67    34           0     126    0    NaN  2018    6
# 66632        4598 -11.67    37           0     112    0    NaN  2018    6
# 66633        4152 -11.67    34           0       0    0    NaN  2018    6
# 66634        4105 -11.67    45           0       0    0    NaN  2018    6
#
#        DIA  HORA  MINUTO  TIPO_Nodo
# 0       27     8      17          3
# 1       27     8      17          3
# 2       27     8      17          0
# 3       27     8      18          0
# 4       27     8      18          3
# ...    ...   ...     ...        ...
# 66630   23     5      54          0
# 66631   23     5      55          0
# 66632   23     5      55          0
# 66633   23     5      56          0
# 66634   23     5      56          0
#
# [66635 rows x 19 columns]

# %% [markdown]
# ## Suprime las columnas que no se necesitan

# %%
try:
    df.drop(columns=['T_NODO', 'TRY', 'FECHA', 'Carga', 'RSSI', 'T_SERVIDOR', 'TIPO_Nodo'], inplace = True)
except KeyError:
    pass
df
# Out:
#        id_Variable  id_nodo  Temperatura  Humedad  Hum. Tierra  Nivel_UV  \
# 0                1        4            0        0         0.00         0
# 1                2        5            0        0         0.00         0
# 2                3        3           30       42         0.01         0
# 3                4        2           30       44         0.01         0
# 4                5        6           30       44         0.01        12
# ...            ...      ...          ...      ...          ...       ...
# 66630        66631        5           22       22         8.68         0
# 66631        66632        2           23       21         2.26        12
# 66632        66633        5           22       22         8.68         0
# 66633        66634        2           22       22         3.22        12
# 66634        66635        5           22       22         8.68         0
#
#        INT. LUMÍN   AÑO  MES  DIA  HORA  MINUTO
# 0               0  2018    4   27     8      17
# 1               0  2018    4   27     8      17
# 2            1038  2018    4   27     8      17
# 3             791  2018    4   27     8      18
# 4            5777  2018    4   27     8      18
# ...           ...   ...  ...  ...   ...     ...
# 66630        5085  2018    6   23     5      54
# 66631        5219  2018    6   23     5      55
# 66632        4598  2018    6   23     5      55
# 66633        4152  2018    6   23     5      56
# 66634        4105  2018    6   23     5      56
#
# [66635 rows x 12 columns]

# %% [markdown]
# ## Atrasa la columna HORA del mes mayo en tres unidades, la hora estaba adelantada para esos registros

# %%
ind_rem = [[x,int(df.HORA[x])-3] for x in range(len(df)) if df.MES[x] < 6]
df.loc[pd.DataFrame(ind_rem).iloc[:,0],'HORA'] = pd.DataFrame(ind_rem).iloc[:,1].values
ind_rem = [[x, df.HORA[x]+24,df.DIA[x]-1] for x in range(len(df)) if df.HORA[x]<0]
df.loc[pd.DataFrame(ind_rem).iloc[:,0],'HORA'] = pd.DataFrame(ind_rem).iloc[:,1].values
df.loc[pd.DataFrame(ind_rem).iloc[:,0],'DIA'] = pd.DataFrame(ind_rem).iloc[:,2].values

# %% [markdown]
# ## Cambia los nombres de las columnas

# %%
old_names = ['id_Variable','id_nodo','Temperatura','Humedad','Hum. Tierra','Nivel_UV','INT. LUMÍN'] 
new_names = ['id_Variable','NODO','TEMPERATURA','HUMEDAD RELATIVA','HUMEDAD DE LA TIERRA','NIVEL UV','INTENSIDAD LUMÍNICA']
df.rename(columns=dict(zip(old_names, new_names)), inplace=True)
df
# Out:
#        id_Variable  NODO  TEMPERATURA  HUMEDAD RELATIVA  HUMEDAD DE LA TIERRA  \
# 0                1     4            0                 0                  0.00
# 1                2     5            0                 0                  0.00
# 2                3     3           30                42                  0.01
# 3                4     2           30                44                  0.01
# 4                5     6           30                44                  0.01
# ...            ...   ...          ...               ...                   ...
# 66630        66631     5           22                22                  8.68
# 66631        66632     2           23                21                  2.26
# 66632        66633     5           22                22                  8.68
# 66633        66634     2           22                22                  3.22
# 66634        66635     5           22                22                  8.68
#
#        NIVEL UV  INTENSIDAD LUMÍNICA   AÑO  MES  DIA  HORA  MINUTO
# 0             0                    0  2018    4   27     5      17
# 1             0                    0  2018    4   27     5      17
# 2             0                 1038  2018    4   27     5      17
# 3             0                  791  2018    4   27     5      18
# 4            12                 5777  2018    4   27     5      18
# ...         ...                  ...   ...  ...  ...   ...     ...
# 66630         0                 5085  2018    6   23     5      54
# 66631        12                 5219  2018    6   23     5      55
# 66632         0                 4598  2018    6   23     5      55
# 66633        12                 4152  2018    6   23     5      56
# 66634         0                 4105  2018    6   23     5      56
#
# [66635 rows x 12 columns]

# %% [markdown]
# ## Se introduce un cero antes de las unidades de las columnas MES, DIA, HORA, MINUTO

# %%
ind_rem = {}
for i in ['MES','DIA','HORA','MINUTO']:
    ind_rem[i] = [[x,'0'+str(df[i][x])] for x in range(len(df)) if df[i][x] < 10]
    df.loc[pd.DataFrame(ind_rem[i]).iloc[:,0],i] = pd.DataFrame(ind_rem[i]).iloc[:,1].values
df
# Out:
#        id_Variable  NODO  TEMPERATURA  HUMEDAD RELATIVA  HUMEDAD DE LA TIERRA  \
# 0                1     4            0                 0                  0.00
# 1                2     5            0                 0                  0.00
# 2                3     3           30                42                  0.01
# 3                4     2           30                44                  0.01
# 4                5     6           30                44                  0.01
# ...            ...   ...          ...               ...                   ...
# 66630        66631     5           22                22                  8.68
# 66631        66632     2           23                21                  2.26
# 66632        66633     5           22                22                  8.68
# 66633        66634     2           22                22                  3.22
# 66634        66635     5           22                22                  8.68
#
#        NIVEL UV  INTENSIDAD LUMÍNICA   AÑO MES DIA HORA MINUTO
# 0             0                    0  2018  04  27   05     17
# 1             0                    0  2018  04  27   05     17
# 2             0                 1038  2018  04  27   05     17
# 3             0                  791  2018  04  27   05     18
# 4            12                 5777  2018  04  27   05     18
# ...         ...                  ...   ...  ..  ..  ...    ...
# 66630         0                 5085  2018  06  23   05     54
# 66631        12                 5219  2018  06  23   05     55
# 66632         0                 4598  2018  06  23   05     55
# 66633        12                 4152  2018  06  23   05     56
# 66634         0                 4105  2018  06  23   05     56
#
# [66635 rows x 12 columns]

# %% [markdown]
# ## Se crea una columna con la estructura AÑO+MES+DIA+HORA+MINUTO

# %%
df['TIME'] = [str(df.AÑO[i])+str(df.MES[i])+str(df.DIA[i])+str(df.HORA[i])+str(df.MINUTO[i]) for i in range(len(df))]
df.TIME
# Out:
# 0        201804270517
# 1        201804270517
# 2        201804270517
# 3        201804270518
# 4        201804270518
#              ...
# 66630    201806230554
# 66631    201806230555
# 66632    201806230555
# 66633    201806230556
# 66634    201806230556
# Name: TIME, Length: 66635, dtype: object

# %% [markdown]
# ## Convierte la columna TIME al fomato Timestamp

# %%
df['TIME'] = [pd.Timestamp(x) for x in df['TIME']]
df
# Out:
#        id_Variable  NODO  TEMPERATURA  HUMEDAD RELATIVA  HUMEDAD DE LA TIERRA  \
# 0                1     4            0                 0                  0.00
# 1                2     5            0                 0                  0.00
# 2                3     3           30                42                  0.01
# 3                4     2           30                44                  0.01
# 4                5     6           30                44                  0.01
# ...            ...   ...          ...               ...                   ...
# 66630        66631     5           22                22                  8.68
# 66631        66632     2           23                21                  2.26
# 66632        66633     5           22                22                  8.68
# 66633        66634     2           22                22                  3.22
# 66634        66635     5           22                22                  8.68
#
#        NIVEL UV  INTENSIDAD LUMÍNICA   AÑO MES DIA HORA MINUTO  \
# 0             0                    0  2018  04  27   05     17
# 1             0                    0  2018  04  27   05     17
# 2             0                 1038  2018  04  27   05     17
# 3             0                  791  2018  04  27   05     18
# 4            12                 5777  2018  04  27   05     18
# ...         ...                  ...   ...  ..  ..  ...    ...
# 66630         0                 5085  2018  06  23   05     54
# 66631        12                 5219  2018  06  23   05     55
# 66632         0                 4598  2018  06  23   05     55
# 66633        12                 4152  2018  06  23   05     56
# 66634         0                 4105  2018  06  23   05     56
#
#                      TIME
# 0     2018-04-27 05:17:00
# 1     2018-04-27 05:17:00
# 2     2018-04-27 05:17:00
# 3     2018-04-27 05:18:00
# 4     2018-04-27 05:18:00
# ...                   ...
# 66630 2018-06-23 05:54:00
# 66631 2018-06-23 05:55:00
# 66632 2018-06-23 05:55:00
# 66633 2018-06-23 05:56:00
# 66634 2018-06-23 05:56:00
#
# [66635 rows x 13 columns]

# %% [markdown]
# ## Suprime las columnas que no se van a utilizar

# %%
try:
    df.drop(columns = ['id_Variable','AÑO','MES','DIA','MINUTO'], inplace = True)
except KeyError:
    pass

# %% [markdown]
# ## Elimina los elementos de df anteriores al registro 2882, correspondientes a pruebas

# %%
if len(df) == 50501:
    df = df.iloc[2822::,:].reset_index(drop = True)

# %%
df.index = df.TIME
df.drop(columns = 'TIME', inplace = True)
df
# Out:
#                      NODO  TEMPERATURA  HUMEDAD RELATIVA  \
# TIME
# 2018-04-27 05:17:00     4            0                 0
# 2018-04-27 05:17:00     5            0                 0
# 2018-04-27 05:17:00     3           30                42
# 2018-04-27 05:18:00     2           30                44
# 2018-04-27 05:18:00     6           30                44
# ...                   ...          ...               ...
# 2018-06-23 05:54:00     5           22                22
# 2018-06-23 05:55:00     2           23                21
# 2018-06-23 05:55:00     5           22                22
# 2018-06-23 05:56:00     2           22                22
# 2018-06-23 05:56:00     5           22                22
#
#                      HUMEDAD DE LA TIERRA  NIVEL UV  INTENSIDAD LUMÍNICA HORA
# TIME
# 2018-04-27 05:17:00                  0.00         0                    0   05
# 2018-04-27 05:17:00                  0.00         0                    0   05
# 2018-04-27 05:17:00                  0.01         0                 1038   05
# 2018-04-27 05:18:00                  0.01         0                  791   05
# 2018-04-27 05:18:00                  0.01        12                 5777   05
# ...                                   ...       ...                  ...  ...
# 2018-06-23 05:54:00                  8.68         0                 5085   05
# 2018-06-23 05:55:00                  2.26        12                 5219   05
# 2018-06-23 05:55:00                  8.68         0                 4598   05
# 2018-06-23 05:56:00                  3.22        12                 4152   05
# 2018-06-23 05:56:00                  8.68         0                 4105   05
#
# [66635 rows x 7 columns]

# %%
# convierte a entero los registros de la columna HORA
df.HORA = [int(df.HORA[x]) for x in range(len(df))]

# %%
n = df.NODO.value_counts()
# imprime los nodos contenidos en df y la cantidad de registros que posee
print(n)
nodos  = n.index.tolist()
# Out:
# 3    18871
# 2    17882
# 5    17731
# 8     8678
# 6     2113
# 4      654
# 7      356
# 9      350
# Name: NODO, dtype: int64

# %% [markdown]
# ## Separa los nodos

# %%
tablas = {}
for i in nodos:
    tablas[i] = (df.query('NODO == %s' %i)).copy()#.reset_index(drop=False))
    tablas[i].drop(columns = ['NODO'],inplace=True)
    tablas[i] = tablas[i][~tablas[i].index.duplicated(keep='first')]

# %% [markdown]
# ### Guarda los registros de los nodos en datasets separados

# %%
for i in nodos:
    (tablas[i]).to_csv('medidas_nodo%d.csv'%i)

# %% [markdown]
# ### Guarda un nuevo .csv de las mediciones

# %%
print(len(df))
df = df[~df.index.duplicated(keep='first')]
print(len(df))
df.to_csv('medidas_update.csv')
# Out:
# 66635
# 23138
