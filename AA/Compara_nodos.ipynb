# %% [markdown]
# # Compara nodos para saber cuál es el que presenta los mejores datos para cada valriable y qué periodo de tiempo corresponden

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
n2 = pd.read_csv('medidas_nodo2',parse_dates=True,index_col=0)

# %%
a=n2.TEMPERATURA.rolling(2000).median()
b=a[a.isnull().values].index
rolling_median_inv=n2.TEMPERATURA.iloc[::-1].rolling(2000).median().iloc[::-1]

# %%
a.loc[b] = rolling_median_inv.loc[b]

# %%
plt.plot(a)
plt.plot(n2.TEMPERATURA)

# %%
plt.figure(figsize=[20,5])
plt.plot(n2.TEMPERATURA)
nv=n2.TEMPERATURA[n2.TEMPERATURA==30].index
f = [n2.index.get_loc(x) for x in nv]
n2.TEMPERATURA.iloc[f] =50
#plt.figure(figsize=[20,5])
#plt.plot(n2.TEMPERATURA)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     173         try:
# --> 174             return self._convert_to_indexer(key, is_setter=True)
#     175         except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    2118         try:
# -> 2119             self._validate_key(obj, axis)
#    2120             return obj
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1966
# -> 1967             if len(arr) and (arr.max() >= l or arr.min() < -l):
#    1968                 raise IndexError("positional indexers are out-of-bounds")
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims)
# ...

# %%
n2.TEMPERATURA.iloc[f]

# %%
from datetime import timedelta

# %%
nvalores[0]+
