# %%
import pandas as pd
df = pd.read_csv('nodo2_periodo2.csv',parse_dates=True,index_col=0)
display(df.columns)

import numpy as np

import matplotlib.pyplot as plt
df =df.iloc[:,3]
plt.plot(df.value_counts())
# Out:
# Index(['HUMEDAD DE LA TIERRA', 'HUMEDAD RELATIVA', 'INTENSIDAD LUMÍNICA',
#        'TEMPERATURA'],
#       dtype='object')

# %%
plt.subplot(121)
plt.hist(df,log='True')
plt.subplot(122)
plt.hist(df)
# Out:
# (array([2.100e+01, 0.000e+00, 1.700e+01, 1.000e+00, 4.000e+00, 1.054e+03,
#         2.364e+03, 5.670e+02, 1.100e+01, 9.400e+01]),
#  array([-20., -12.,  -4.,   4.,  12.,  20.,  28.,  36.,  44.,  52.,  60.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Si ud ve que hay mucho outlier..... quitelos con el siguiente código :D

# %%
df.hist(bins=15)
upper, lower = np.percentile(df, [1,99])
y = np.clip(df, upper, lower)
pd.Series(y).hist(bins=15)

# %%
plt.scatter(df,y)

# %%
plt.subplot(211)
plt.plot(df)
plt.subplot(212)
plt.plot(y)

# %%
inicio = df.index[0]
fin =df.index[-1]

# %%
inicio
# Out:
# Timestamp('2018-05-23 10:08:00')

# %% [markdown]
# # Creamo la columna faltante :D

# %%
df1 = pd.read_csv('nodo2_periodo2.csv',parse_dates=True,index_col=0)
#df1['TIEMPO'] = df1.index.hour*60+df.index.minute
#df.info()
inicio = df1.index[0]
fin =df1.index[-1]

df = pd.read_csv('medidas_nodo2.csv',parse_dates=True,index_col=0)
df['faltante'] = 0
df = df.loc[inicio:fin,:]
df = df.asfreq('60s')
df['faltante'][df['faltante'].isnull()==True] = 1
df = df.ffill().bfill()
display(df.head())
df.info()

# %%
d[d['faltante']==1].plot(style='.')

# %%
d['s'] = d.iloc[:,0].values*d.iloc[:,1].values

# %%
import numpy as np
pc = periodo2[2].columns
ls, li = np.percentile(periodo2[2].values, [25,87])
n2 = np.clip(periodo2[2].values, ls, li)
periodo2[2] = pd.DataFrame(n2)
periodo2[2].columns = pc



my_dataframe["my_feature_name"].apply(lambda x: max(x, 0))
# Out:
#                      TEMPERATURA  faltante   d     s
# TIME
# 2018-05-23 10:08:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:09:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:10:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:11:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:12:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:13:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:14:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:15:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:16:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:17:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:18:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:19:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:20:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:21:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:22:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:23:00         35.0       0.0 NaN   0.0
# 2018-05-23 10:24:00         35.0       1.0 NaN  35.0
# ...
