# %%
import pandas as pd
import matplotlib.pylab as plt
from matplotlib import cm
import seaborn as sns
import funs
from scipy.stats.stats import pearsonr
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')
# Se define un límite para las filas de los dataframes que se presenten en el notebook
pd.options.display.max_rows = 10
# Out:
# C:\Users\Jergb\Anaconda3\lib\site-packages\ggplot\utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,

# %%
plt.rcParams['figure.figsize'] = [16, 8]
periodo = 2
nodosp={}
for i in [2,3,5]:
    nodosp[i] = pd.read_csv('nodo%d_periodo%d.csv'%(i,periodo),
                                           parse_dates=True,index_col=0)
    plt.figure()
    plt.suptitle('Nodo %d'%i)
    for pos,variable in enumerate(nodosp[i]):
        plt.subplot(2,2,pos+1)
        plt.plot(nodosp[i].loc[:,variable])
        plt.title('%s'%variable)

# %%
nodo = nodosp[3]
col = 4
inicio = str(nodo.index.year[0])+'-'+str(nodo.index.month[0])+'-'+str(nodo.index.day[0])
fin = str(nodo.index.year[-1])+'-'+str(nodo.index.month[-1])+'-'+str(nodo.index.day[-1])

# Ejemplo de descomposición de serie de tiempo
fig, axes = plt.subplots(ncols=4, nrows=4, sharex=True, figsize=(14,6))

def plotseasonal(res, axes ):
    res.observed.plot(ax=axes[0], legend=False)
    axes[0].set_ylabel('Observada')
    res.trend.plot(ax=axes[1], legend=False)
    axes[1].set_ylabel('Tendencia')
    res.seasonal.plot(ax=axes[2], legend=False)
    axes[2].set_ylabel('Seasonal')
    res.resid.plot(ax=axes[3], legend=False)
    axes[3].set_ylabel('Residual')

for pos, var in enumerate(nodo):
    des = sm.tsa.seasonal_decompose(nodo.loc[:,var],
                                               model='additive', freq=60)  

    plotseasonal(des, axes[:,pos])
    plt.tight_layout()

# %%
for var in nodo:
    c = max([nodo.loc[:,var][nodo.index.hour==h].count() for h in range(12)])
    
    temp = pd.DataFrame(index=range(c))
    
    for h in range(24):
        temp[h] = pd.Series(nodo.loc[:,var][nodo.index.hour==h].values)
    det = temp.describe()
    
    plt.figure()
    temp.boxplot()
    plt.plot(range(1,25),det.loc['std',:],'-o',label='DESVIACIÓN ESTANDAR DIARIA')
    plt.plot(range(1,25),det.loc['mean',:],'-o',label='MEDIA DIARIA')
    plt.legend()
    plt.xlabel('HORA',fontsize=12)
    plt.ylabel('%s'%var,fontsize=12)
    plt.title('CLIMATOLOGíA DIARIA\n%s (%s a %s)'%(var,inicio,fin),fontsize=14)
    #plt.savefig('plot_%s.png'%nodo.columns[col], dpi=300)

# %%
nodo['hora'] = nodo.index.hour
nodo['min'] = nodo.index.minute

# %%
plt.subplot(211)
sns.swarmplot(x='hora',y='TEMPERATURA',data=nodo)
plt.subplot(212)
sns.boxplot(x='hora',y='TEMPERATURA',data=nodo)

# %%
plt.subplot(211)
sns.swarmplot(x='hora',y='HUMEDAD RELATIVA',data=nodo)
plt.subplot(212)
sns.boxplot(x='hora',y='HUMEDAD RELATIVA',data=nodo)

# %%
plt.subplot(211)
sns.swarmplot(x='hora',y='INTENSIDAD LUMÍNICA',data=nodo)
plt.subplot(212)
sns.boxplot(x='hora',y='INTENSIDAD LUMÍNICA',data=nodo)

# %%
import seaborn as sns

for var in nodo:
    #c = max([nodo.loc[:,var][nodo.index.hour==h].count() for h in range(12)])
    
    #temp = pd.DataFrame(index=range(c))
    
    #for h in range(24):
     #   temp[h] = pd.Series(nodo.loc[:,var][nodo.index.hour==h].values)
    det = nodo[var].describe()
    
    plt.figure()
    #temp.boxplot()
    sns.boxplot(x='hora',y=var,data=nodo)
    plt.plot(range(24),det.loc['std',:],'-o',label='DESVIACIÓN ESTANDAR DIARIA')
    plt.plot(range(24),det.loc['mean',:],'-o',label='MEDIA DIARIA')
    plt.legend()
    #plt.xlabel('HORA',fontsize=12)
    #plt.ylabel('%s'%var,fontsize=12)
    plt.title('CLIMATOLOGíA DIARIA\n%s (%s a %s)'%(var,inicio,fin),fontsize=14)
    #plt.savefig('plot_%s.png'%nodo.columns[col], dpi=300)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-24-754672a93de1> in <module>()
#      13     #temp.boxplot()
#      14     sns.boxplot(x='hora',y=var,data=nodo)
# ---> 15     plt.plot(range(24),det.loc['std',:],'-o',label='DESVIACIÓN ESTANDAR DIARIA')
#      16     plt.plot(range(24),det.loc['mean',:],'-o',label='MEDIA DIARIA')
#      17     plt.legend()
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     873
#     874         # no multi-index, so validate all of the indexers
# --> 875         self._has_valid_tuple(tup)
#     876
#     877         # ugly hack for GH #836
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     218         for i, k in enumerate(key):
#     219             if i >= self.obj.ndim:
# --> 220                 raise IndexingError('Too many indexers')
#     221             try:
#     222                 self._validate_key(k, i)
#
# IndexingError: Too many indexers

# %% [markdown]
# # Falta hacer a media horaria diaria, reducir cada día a 24 valores medios y hacer la climatologia para eso.

# %% [markdown]
# # Analizar la climatologia simultanea de los nodos.....
